# %%
import numpy as np
import math 
from svmutil import *
import multiprocessing as mp

# %%
def toBinaryClass(yList,label):
    return [1 - 2*(y != label) for y in yList]

def SparseToDense(xTrain):
    x = xTrain.copy()
    xList = [x.get(i) for i in range(1,37)]
    return np.array([0 if x == None else x for x in xList])

# %%
#question 15
def GetW(yTrain,xTrain):
    yTrain = yTrain.copy()
    xTrain = xTrain.copy()
    m = svm_train(yTrain, xTrain, '-c 10 -t 0')
    w = np.zeros(36)
    for i in range(m.l):
        w += m.sv_coef[0][i]*SparseToDense(xTrain[m.sv_indices[i]-1])
    return w, m.l
        
    
yTrain, xTrain = svm_read_problem('hw5_data/satimage.scale')
newy3 = toBinaryClass(yTrain,3)
w, l = GetW(newy3, xTrain)
print('||w|| = {:.4f}\tl = {}'.format(np.linalg.norm(w),l))
# Out:
# ||w|| = 8.4571	l = 500

# %%
#question 16 17
m = None
def kernel(xn, xm):
    return (1+np.dot(xn,xm))**2

def mpCalculation(args):
    y, x, xTest_i = args
    gSVM = 0
    for j in range (m.l):
        SVMidx = m.sv_indices[j]-1
        gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i))
    return (gSVM - m.rho[0] )* y < 0

def Ein(y, x):
    global m
    y, x = y.copy(), x.copy()
    m = svm_train(y, x,'-t 1 -d 2 -g 1 -r 1 -c 10')
    pool = mp.Pool(mp.cpu_count())
    EinList = pool.map(mpCalculation, [(_y, x, x[i]) for i, _y in enumerate(y)])
    return m.l, np.average(EinList)

# %%
#question 16 17
yList = [toBinaryClass(yTrain, i) for i in range(1,6)]
EinList = [Ein(y,xTrain) for y in yList]
for i, (cnt, Ein) in enumerate(EinList):
    print('***{} versus not {}:\nnumber of SVM: {}\tEin = {:.4f}\n'.format(i+1, i+1, cnt, Ein))
# Out:
# ***1 versus not 1:
# number of SVM: 145	Ein = 0.0007
#
# ***2 versus not 2:
# number of SVM: 87	Ein = 0.0000
#
# ***3 versus not 3:
# number of SVM: 433	Ein = 0.0223
#
# ***4 versus not 4:
# number of SVM: 712	Ein = 0.0401
#
# ***5 versus not 5:
# number of SVM: 259	Ein = 0.0068

# %%
#question 18 19
m = None
def kernel(xn, xm, gamma):
    return math.exp(-gamma * np.linalg.norm(xn - xm) ** 2)

def mpCalculation(args):
    y, x, xTest_i, gamma = args
    gSVM = 0
    for j in range (m.l):
        SVMidx = m.sv_indices[j]-1
        gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i), gamma)
    return (gSVM - m.rho[0]) * y < 0

def Eout(y, x, yTest, xTest, C, gamma):
    global m
    y, x = y.copy(), x.copy()
    m = svm_train(y, x, '-s 0 -t 2 -c '+str(C)+' -g '+str(gamma))
    pool = mp.Pool(mp.cpu_count())
    EoutList = pool.map(mpCalculation, [(y, x, xTest[i], gamma) for i, y in enumerate(yTest)])
    return np.average(EoutList)

# %%
#question 18
yTest, xTest = svm_read_problem('hw5_data/satimage.scale.t')
yTrain = toBinaryClass(yTrain, 6)
yTest = toBinaryClass(yTest, 6)

for order in range(-2, 3):
    C = 10**order
    print("C = {}\tEout = {:.6f}".format(C, Eout(yTrain, xTrain, yTest, xTest, C, 10)))
# Out:
# C = 0.01	Eout = 0.235000
# C = 0.1	Eout = 0.163500
# C = 1	Eout = 0.106500
# C = 10	Eout = 0.097000

# %%
#question 19
yTest, xTest = svm_read_problem('hw5_data/satimage.scale.t')
yTrain = toBinaryClass(yTrain, 6)
yTest = toBinaryClass(yTest, 6)

for order in range(-1, 4):
    gamma = 10**order
    print("gamma = {}\tEout = {:.6f}".format(gamma, Eout(yTrain, xTrain, yTest, xTest, 0.1, gamma)))
# Out:
# gamma = 0.1	Eout = 0.040000
# gamma = 1	Eout = 0.048500
# Process ForkPoolWorker-195:
# Process ForkPoolWorker-191:
# Process ForkPoolWorker-193:
# Process ForkPoolWorker-185:
# Process ForkPoolWorker-199:
# Process ForkPoolWorker-192:
# Process ForkPoolWorker-200:
# Process ForkPoolWorker-189:
# Process ForkPoolWorker-186:
# Process ForkPoolWorker-194:
# Process ForkPoolWorker-201:
# Process ForkPoolWorker-202:
# Process ForkPoolWorker-183:
# Process ForkPoolWorker-197:
# Process ForkPoolWorker-196:
# Process ForkPoolWorker-198:
# Process ForkPoolWorker-203:
# Process ForkPoolWorker-190:
# Process ForkPoolWorker-181:
# Process ForkPoolWorker-182:
# Process ForkPoolWorker-187:
# Process ForkPoolWorker-204:
# Process ForkPoolWorker-184:
# Process ForkPoolWorker-188:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-215:
# Traceback (most recent call last):
# Process ForkPoolWorker-214:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-213:
# Process ForkPoolWorker-207:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-205:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-212:
# Traceback (most recent call last):
# Process ForkPoolWorker-216:
# Process ForkPoolWorker-211:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-206:
# Process ForkPoolWorker-208:
# Process ForkPoolWorker-209:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-210:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "<ipython-input-12-75d550cee518>", line 11, in mpCalculation
#     gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i), gamma)
#   File "<ipython-input-12-75d550cee518>", line 11, in mpCalculation
#     gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i), gamma)
#   File "<ipython-input-12-75d550cee518>", line 11, in mpCalculation
#     gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i), gamma)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-12-75d550cee518>", line 11, in mpCalculation
#     gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i), gamma)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-10-5a8ae9df8352>", line 7, in SparseToDense
#     return np.array([0 if x == None else x for x in xList])
#   File "<ipython-input-10-5a8ae9df8352>", line 6, in SparseToDense
#     xList = [x.get(i) for i in range(1,37)]
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "<ipython-input-10-5a8ae9df8352>", line 6, in SparseToDense
#     xList = [x.get(i) for i in range(1,37)]
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-12-75d550cee518>", line 11, in mpCalculation
#     gSVM += m.sv_coef[0][j]*kernel(SparseToDense(x[SVMidx]), SparseToDense(xTest_i), gamma)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt

# %%
#question 19
print('gamma = 0.1, Eout = ' + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,0.1)))
print('gamma = 1, Eout = ' + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,1)))
print('gamma = 10, Eout = '  + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,10)))
print('gamma = 100, Eout = ' + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,100)))
print('gamma = 1000, Eout = '+ str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,1000)))
# Out:
# number of SVM = 1102
# -1.521412613816365
# gamma = 0.1, Eout = 0.235
# number of SVM = 1175
# -0.9289417665896331
# gamma = 1, Eout = 0.235
# number of SVM = 3883
# -0.951574004557945
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-044eed8f8fc6> in <module>
#       2 print('gamma = 0.1, Eout = ' + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,0.1)))
#       3 print('gamma = 1, Eout = ' + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,1)))
# ----> 4 print('gamma = 10, Eout = '  + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,10)))
#       5 print('gamma = 100, Eout = ' + str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,100)))
#       6 print('gamma = 1000, Eout = '+ str(calculate_Eout(newy6,xTrain,newYTest,xTest,0.1,1000)))
#
# <ipython-input-34-9c634d455b3c> in calculate_Eout(y, x, yTest, xTest, C, gamma)
#      17         for j in range (m.l):
#      18             SVM_index = m.sv_indices[j]-1
# ---> 19             gSVM = gSVM + (m.sv_coef[0][j] * Gkernel(sparse_to_dense(x[SVM_index]),sparse_to_dense(xTest[i]),gamma) + b)
#      20         if gSVM * yTest[i] < 0:
#      21             E_out += 1
#
# <ipython-input-1-2512d935ece1> in sparse_to_dense(xTrain)
#      25         i = index +1
#      26         if x.get(i) != None:
# ---> 27             newX[index] = x.get(i)
#      28         else:
#      29             newX[index] = 0
#
# KeyboardInterrupt:

# %%
#question 20
